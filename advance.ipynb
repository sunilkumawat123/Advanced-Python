# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('placement.csv')
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df=df.iloc[:4, :3] # iloc[row_range, column_range]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3,['cgpa','placed']] # loc[row_range, column_range]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
s= df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=b= df.empty # return true if there any missing data in dataframe otherwise false
b
# Out:
# False

# %%
df.isnull().sum()  # check missing value
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna() # for remove missing data
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
i=df.ndim # number of axis
i
# Out:
# 2

# %%
t=df.shape # rows,columns
t
# Out:
# (100, 3)

# %%
d=df.size # row count * column count
d
# Out:
# 300

# %%
df.values
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df=df.copy()

# %%
p= df.sort_values(by='resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
df['cgpa']=df['cgpa'].astype(int)

# %%
p['cgpa']= p['cgpa'].astype(int)

# %%
df=df.drop(columns= ['cgpa'])
df
# Out:
#     resume_score  placed
# 0           6.52       1
# 1           5.17       0
# 2           8.86       1
# 3           7.27       1
# 4           7.30       1
# ..           ...     ...
# 95          6.38       0
# 96          7.76       1
# 97          7.78       0
# 98          5.63       1
# 99          6.61       0
#
# [100 rows x 2 columns]

# %%
df['cgpa']=df['cgpa'].add(4)

# %%
df
# Out:
#      cgpa  resume_score  placed
# 0   12.14          6.52       1
# 1   10.17          5.17       0
# 2   12.27          8.86       1
# 3   10.88          7.27       1
# 4   11.52          7.30       1
# ..    ...           ...     ...
# 95  10.33          6.38       0
# 96  12.23          7.76       1
# 97  10.65          7.78       0
# 98  12.14          5.63       1
# 99  10.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['resume_score']= df['resume_score'].add(4)
df
# Out:
#      cgpa  resume_score  placed
# 0   12.14         10.52       1
# 1   10.17          9.17       0
# 2   12.27         12.86       1
# 3   10.88         11.27       1
# 4   11.52         11.30       1
# ..    ...           ...     ...
# 95  10.33         10.38       0
# 96  12.23         11.76       1
# 97  10.65         11.78       0
# 98  12.14          9.63       1
# 99  10.09         10.61       0
#
# [100 rows x 3 columns]

# %%
df['placed'] = df['placed'].add(4)
df
# Out:
#      cgpa  resume_score  placed
# 0   12.14         10.52       9
# 1   10.17          9.17       8
# 2   12.27         12.86       9
# 3   10.88         11.27       9
# 4   11.52         11.30       9
# ..    ...           ...     ...
# 95  10.33         10.38       8
# 96  12.23         11.76       9
# 97  10.65         11.78       8
# 98  12.14          9.63       9
# 99  10.09         10.61       8
#
# [100 rows x 3 columns]

# %%
df.count()
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
df.max()
# Out:
# cgpa            13.40
# resume_score    13.06
# placed           9.00
# dtype: float64

# %%
df.min()
# Out:
# cgpa            9.27
# resume_score    8.95
# placed          8.00
# dtype: float64

# %%
a=df['cgpa'].mean()
a
# Out:
# 10.942200000000003

# %%
a=df['cgpa'].mode()
a
# Out:
# 0      9.54
# 1      9.76
# 2      9.87
# 3      9.92
# 4     10.00
# 5     10.09
# 6     10.18
# 7     10.34
# 8     12.07
# 9     12.14
# 10    12.22
# Name: cgpa, dtype: float64

# %%
df.filter(items = ['cgpa', 'placed'])
# Out:
#      cgpa  placed
# 0   12.14       9
# 1   10.17       8
# 2   12.27       9
# 3   10.88       9
# 4   11.52       9
# ..    ...     ...
# 95  10.33       8
# 96  12.23       9
# 97  10.65       8
# 98  12.14       9
# 99  10.09       8
#
# [100 rows x 2 columns]

# %%
df[['cgpa','placed']]
# Out:
#      cgpa  placed
# 0   12.14       9
# 1   10.17       8
# 2   12.27       9
# 3   10.88       9
# 4   11.52       9
# ..    ...     ...
# 95  10.33       8
# 96  12.23       9
# 97  10.65       8
# 98  12.14       9
# 99  10.09       8
#
# [100 rows x 2 columns]

# %%
s=df.filter(items= [3,4,5,6],axis=0) # axis=0 means row wise operation
s
# Out:
#     cgpa  resume_score  placed
# 3  10.88         11.27       9
# 4  11.52         11.30       9
# 5  12.77         10.19       9
# 6   9.34         11.09       8

# %%
p=df.rename(columns= {'cgpa':'updated', 'resume_score':'semester_record'})
p
# Out:
#     updated  semester_record  placed
# 0     12.14            10.52       9
# 1     10.17             9.17       8
# 2     12.27            12.86       9
# 3     10.88            11.27       9
# 4     11.52            11.30       9
# ..      ...              ...     ...
# 95    10.33            10.38       8
# 96    12.23            11.76       9
# 97    10.65            11.78       8
# 98    12.14             9.63       9
# 99    10.09            10.61       8
#
# [100 rows x 3 columns]

# %%
df
# Out:
#      cgpa  resume_score  placed
# 0   12.14         10.52       9
# 1   10.17          9.17       8
# 2   12.27         12.86       9
# 3   10.88         11.27       9
# 4   11.52         11.30       9
# ..    ...           ...     ...
# 95  10.33         10.38       8
# 96  12.23         11.76       9
# 97  10.65         11.78       8
# 98  12.14          9.63       9
# 99  10.09         10.61       8
#
# [100 rows x 3 columns]

# %%
df['cgpa']= df['cgpa'].astype(int)

# %%
df['half'] = df['cgpa'].where(df['cgpa']>11,other=0)
df
# Out:
#     cgpa  resume_score  placed  half
# 0     12         10.52       9    12
# 1     10          9.17       8     0
# 2     12         12.86       9    12
# 3     10         11.27       9     0
# 4     11         11.30       9     0
# ..   ...           ...     ...   ...
# 95    10         10.38       8     0
# 96    12         11.76       9    12
# 97    10         11.78       8     0
# 98    12          9.63       9    12
# 99    10         10.61       8     0
#
# [100 rows x 4 columns]

# %%
df=pd.read_csv('covid_toy.csv')
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].map({'Female':0, 'Male':1})
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60       1  103.0    Mild    Kolkata        No
# 1    27       1  100.0    Mild      Delhi       Yes
# 2    42       1  101.0    Mild      Delhi        No
# 3    31       0   98.0    Mild    Kolkata        No
# 4    65       0  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12       0  104.0    Mild  Bangalore        No
# 96   51       0  101.0  Strong    Kolkata       Yes
# 97   20       0  101.0    Mild  Bangalore        No
# 98    5       0   98.0  Strong     Mumbai        No
# 99   10       0   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['cough']=df['cough'].map({'Mild':0, 'Strong':1})
df
# Out:
#     age  gender  fever  cough       city has_covid
# 0    60       1  103.0      0    Kolkata        No
# 1    27       1  100.0      0      Delhi       Yes
# 2    42       1  101.0      0      Delhi        No
# 3    31       0   98.0      0    Kolkata        No
# 4    65       0  101.0      0     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   12       0  104.0      0  Bangalore        No
# 96   51       0  101.0      1    Kolkata       Yes
# 97   20       0  101.0      0  Bangalore        No
# 98    5       0   98.0      1     Mumbai        No
# 99   10       0   98.0      1    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['city']=df['city'].map({'Kolkata':0, 'Bangalore':1,'Delhi':2, 'Mumbai':3})
df
# Out:
#     age  gender  fever  cough  city has_covid
# 0    60       1  103.0      0     0        No
# 1    27       1  100.0      0     2       Yes
# 2    42       1  101.0      0     2        No
# 3    31       0   98.0      0     0        No
# 4    65       0  101.0      0     3        No
# ..  ...     ...    ...    ...   ...       ...
# 95   12       0  104.0      0     1        No
# 96   51       0  101.0      1     0       Yes
# 97   20       0  101.0      0     1        No
# 98    5       0   98.0      1     3        No
# 99   10       0   98.0      1     0       Yes
#
# [100 rows x 6 columns]

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['has_covid']=df['has_covid'].map({'No':0, 'Yes':1})
df
# Out:
#     age  gender  fever  cough  city  has_covid
# 0    60       1  103.0      0     0          0
# 1    27       1  100.0      0     2          1
# 2    42       1  101.0      0     2          0
# 3    31       0   98.0      0     0          0
# 4    65       0  101.0      0     3          0
# ..  ...     ...    ...    ...   ...        ...
# 95   12       0  104.0      0     1          0
# 96   51       0  101.0      1     0          1
# 97   20       0  101.0      0     1          0
# 98    5       0   98.0      1     3          0
# 99   10       0   98.0      1     0          1
#
# [100 rows x 6 columns]

# %%
df.describe()
# Out:
#               age      gender       fever       cough        city  has_covid
# count  100.000000  100.000000   90.000000  100.000000  100.000000     100.00
# mean    44.220000    0.410000  100.844444    0.380000    1.220000       0.45
# std     24.878931    0.494311    2.054926    0.487832    1.069126       0.50
# min      5.000000    0.000000   98.000000    0.000000    0.000000       0.00
# 25%     20.000000    0.000000   99.000000    0.000000    0.000000       0.00
# 50%     45.000000    0.000000  101.000000    0.000000    1.000000       0.00
# 75%     66.500000    1.000000  102.750000    1.000000    2.000000       1.00
# max     84.000000    1.000000  104.000000    1.000000    3.000000       1.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    int64
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    int64
#  4   city       100 non-null    int64
#  5   has_covid  100 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 4.8 KB

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.dropna()
# Out:
#     age  gender  fever  cough  city  has_covid
# 0    60       1  103.0      0     0          0
# 1    27       1  100.0      0     2          1
# 2    42       1  101.0      0     2          0
# 3    31       0   98.0      0     0          0
# 4    65       0  101.0      0     3          0
# ..  ...     ...    ...    ...   ...        ...
# 95   12       0  104.0      0     1          0
# 96   51       0  101.0      1     0          1
# 97   20       0  101.0      0     1          0
# 98    5       0   98.0      1     3          0
# 99   10       0   98.0      1     0          1
#
# [90 rows x 6 columns]

# %%
df
# Out:
#     age  gender  fever  cough  city  has_covid
# 0    60       1  103.0      0     0          0
# 1    27       1  100.0      0     2          1
# 2    42       1  101.0      0     2          0
# 3    31       0   98.0      0     0          0
# 4    65       0  101.0      0     3          0
# ..  ...     ...    ...    ...   ...        ...
# 95   12       0  104.0      0     1          0
# 96   51       0  101.0      1     0          1
# 97   20       0  101.0      0     1          0
# 98    5       0   98.0      1     3          0
# 99   10       0   98.0      1     0          1
#
# [100 rows x 6 columns]

# %%
df.count()
# Out:
# age          100
# gender       100
# fever         90
# cough        100
# city         100
# has_covid    100
# dtype: int64

# %%
df.min()
# Out:
# age           5.0
# gender        0.0
# fever        98.0
# cough         0.0
# city          0.0
# has_covid     0.0
# dtype: float64

# %%
df.max()
# Out:
# age           84.0
# gender         1.0
# fever        104.0
# cough          1.0
# city           3.0
# has_covid      1.0
# dtype: float64

# %%
df['cough']=df['cough'].sub(2)

# %%
df
# Out:
#     age  gender  fever  cough  city  has_covid
# 0    60       1  103.0      0     0          0
# 1    27       1  100.0      0     2          1
# 2    42       1  101.0      0     2          0
# 3    31       0   98.0      0     0          0
# 4    65       0  101.0      0     3          0
# ..  ...     ...    ...    ...   ...        ...
# 95   12       0  104.0      0     1          0
# 96   51       0  101.0      1     0          1
# 97   20       0  101.0      0     1          0
# 98    5       0   98.0      1     3          0
# 99   10       0   98.0      1     0          1
#
# [100 rows x 6 columns]

# %%
df['cough']=df['cough'].add(2)
df
# Out:
#     age  gender  fever  cough  city  has_covid
# 0    60       1  103.0      2     0          0
# 1    27       1  100.0      2     2          1
# 2    42       1  101.0      2     2          0
# 3    31       0   98.0      2     0          0
# 4    65       0  101.0      2     3          0
# ..  ...     ...    ...    ...   ...        ...
# 95   12       0  104.0      2     1          0
# 96   51       0  101.0      3     0          1
# 97   20       0  101.0      2     1          0
# 98    5       0   98.0      3     3          0
# 99   10       0   98.0      3     0          1
#
# [100 rows x 6 columns]

# %%
df.size
# Out:
# 600

# %%
df.shape
# Out:
# (100, 6)

# %%
df.value_counts()
# Out:
# age  gender  fever  cough  city  has_covid
# 27   1       100.0  2      2     1            2
# 5    0       98.0   3      3     0            1
# 65   1       99.0   2      1     0            1
#      0       98.0   2      3     1            1
# 64   1       102.0  2      1     1            1
#                                              ..
# 24   0       102.0  3      1     1            1
# 23   1       98.0   3      3     1            1
# 22   0       99.0   2      1     1            1
# 20   1       102.0  3      2     0            1
# 83   1       103.0  2      0     0            1
# Name: count, Length: 89, dtype: int64

# %%
df= df.sort_values(by='city')

# %%
df
# Out:
#     age  gender  fever  cough  city  has_covid
# 0    60       1  103.0      2     0          0
# 31   83       1  103.0      2     0          0
# 33   26       0   98.0      2     0          0
# 37   55       1  100.0      2     0          0
# 39   50       0  103.0      2     0          0
# ..  ...     ...    ...    ...   ...        ...
# 84   69       0   98.0      3     3          0
# 7    20       0    NaN      3     3          1
# 80   14       0   99.0      2     3          1
# 46   19       0  101.0      2     3          0
# 49   44       1  104.0      2     3          0
#
# [100 rows x 6 columns]

# %%
df=df.dropna()

# %%
df['fever']= df['fever'].astype(int)
df
# Out:
# <ipython-input-119-74e871d6b4dd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fever']= df['fever'].astype(int)
#     age  gender  fever  cough  city  has_covid
# 0    60       1    103      2     0          0
# 31   83       1    103      2     0          0
# 33   26       0     98      2     0          0
# 37   55       1    100      2     0          0
# 39   50       0    103      2     0          0
# ..  ...     ...    ...    ...   ...        ...
# 34   74       1    102      2     3          1
# 84   69       0     98      3     3          0
# 80   14       0     99      2     3          1
# 46   19       0    101      2     3          0
# 49   44       1    104      2     3          0
#
# [90 rows x 6 columns]

# %%
df['half'] = df['fever'].where(df['fever']>100,other=0)
df
# Out:
# <ipython-input-120-9948c139ba6b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['half'] = df['fever'].where(df['fever']>100,other=0)
#     age  gender  fever  cough  city  has_covid  half
# 0    60       1    103      2     0          0   103
# 31   83       1    103      2     0          0   103
# 33   26       0     98      2     0          0     0
# 37   55       1    100      2     0          0     0
# 39   50       0    103      2     0          0   103
# ..  ...     ...    ...    ...   ...        ...   ...
# 34   74       1    102      2     3          1   102
# 84   69       0     98      3     3          0     0
# 80   14       0     99      2     3          1     0
# 46   19       0    101      2     3          0   101
# ...

# %%
top_left_corner_df=df.iloc[:4, :3] # iloc[row_range, column_range]
top_left_corner_df
# Out:
#     age  gender  fever
# 0    60       1    103
# 31   83       1    103
# 33   26       0     98
# 37   55       1    100
